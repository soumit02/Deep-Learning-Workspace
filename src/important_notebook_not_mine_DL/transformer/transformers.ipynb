# %%
# !pip install -U transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.12.1)
# Collecting transformers
#   Downloading transformers-5.13.0-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.20.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers) (0.25.1)
# Requirement already satisfied: safetensors>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.8.0)
# Requirement already satisfied: tqdm>=4.60 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: click>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.29.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.14.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)
# Downloading transformers-5.13.0-py3-none-any.whl (11.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 39.1 MB/s eta 0:00:00
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.12.1
#     Uninstalling transformers-5.12.1:
#       Successfully uninstalled transformers-5.12.1
# Successfully installed transformers-5.13.0

# %% [markdown]
# ## Sentiment Analysis

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis")
classifier("Learning AI/ML is fun.")
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# [{'label': 'POSITIVE', 'score': 0.9998519420623779}]

# %%
# batch of sentences
classifier([
    "I love you",
    "I hate you",
])
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998656511306763},
#  {'label': 'NEGATIVE', 'score': 0.9991129040718079}]

# %% [markdown]
# ## Named Entity Recognition

# %%
ner = pipeline("ner")
ner("My name is Sylvain and I work at Hugging Face in Brooklyn.")
# Out:
# [transformers] No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision 4c53496.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# [transformers] BertForTokenClassification LOAD REPORT from: dbmdz/bert-large-cased-finetuned-conll03-english
# Key                      | Status     |  |
# -------------------------+------------+--+-
# bert.pooler.dense.bias   | UNEXPECTED |  |
# bert.pooler.dense.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [{'entity': 'I-PER',
#   'score': np.float32(0.99938285),
#   'index': 4,
#   'word': 'S',
#   'start': 11,
#   'end': 12},
#  {'entity': 'I-PER',
#   'score': np.float32(0.99815494),
#   'index': 5,
#   'word': '##yl',
#   'start': 12,
#   'end': 14},
#  {'entity': 'I-PER',
#   'score': np.float32(0.99590707),
#   'index': 6,
#   'word': '##va',
#   'start': 14,
#   'end': 16},
#  {'entity': 'I-PER',
#   'score': np.float32(0.99923277),
#   'index': 7,
#   'word': '##in',
#   'start': 16,
#   'end': 18},
#  {'entity': 'I-ORG',
#   'score': np.float32(0.9738931),
#   'index': 12,
#   'word': 'Hu',
#   'start': 33,
#   'end': 35},
#  {'entity': 'I-ORG',
#   'score': np.float32(0.976115),
#   'index': 13,
#   'word': '##gging',
#   'start': 35,
#   'end': 40},
#  {'entity': 'I-ORG',
#   'score': np.float32(0.9887976),
#   'index': 14,
#   'word': 'Face',
#   'start': 41,
#   'end': 45},
#  {'entity': 'I-LOC',
#   'score': np.float32(0.9932106),
#   'index': 16,
#   'word': 'Brooklyn',
#   'start': 49,
#   'end': 57}]

# %% [markdown]
# ## Fill Mask (BERT)

# %%
from transformers import pipeline

# Explicitly declare the model and revision
unmasker = pipeline("fill-mask", model="distilbert/distilroberta-base")

# Use the exact lowercase <mask> token required by RoBERTa models
results = unmasker("In this tutorial we will learn about <mask> transformer.", top_k=3)
print(results)
# Out:
# Loading weights:   0%|          | 0/106 [00:00<?, ?it/s]
# [transformers] RobertaForMaskedLM LOAD REPORT from: distilbert/distilroberta-base
# Key                         | Status     |  |
# ----------------------------+------------+--+-
# roberta.pooler.dense.bias   | UNEXPECTED |  |
# roberta.pooler.dense.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [{'score': 0.009397820569574833, 'token': 5, 'token_str': ' the', 'sequence': 'In this tutorial we will learn about the transformer.'}, {'score': 0.00815515499562025, 'token': 47713, 'token_str': ' asynchronous', 'sequence': 'In this tutorial we will learn about asynchronous transformer.'}, {'score': 0.0073794350028038025, 'token': 17997, 'token_str': ' quantum', 'sequence': 'In this tutorial we will learn about quantum transformer.'}]

# %% [markdown]
# ## Tokenizer Live Demo

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
sequence = "Using a Transformer network is simple"

tokens = tokenizer.tokenize(sequence)
print("tokens:", tokens)

ids = tokenizer.convert_tokens_to_ids(tokens)
print("input IDs:", ids)

inputs = tokenizer(sequence)
print("full encoding:", inputs)

decoded = tokenizer.decode(inputs["input_ids"])
print("decoded:", decoded)
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokens: ['using', 'a', 'transform', '##er', 'network', 'is', 'simple']
# input IDs: [2478, 1037, 10938, 2121, 2897, 2003, 3722]
# full encoding: {'input_ids': [101, 2478, 1037, 10938, 2121, 2897, 2003, 3722, 102], 'token_type_ids': [0, 0, 0, 0, 0, 0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1, 1, 1, 1, 1, 1]}
# decoded: [CLS] using a transformer network is simple [SEP]

# %% [markdown]
# ## Tokenizer Comparison: BERT vs GPT-2

# %%
bert_tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
gpt2_tokenizer = AutoTokenizer.from_pretrained("gpt2")

sentence = "Transformers is amazing"

bert_tokens = bert_tokenizer.tokenize(sentence)
gpt2_tokens = gpt2_tokenizer.tokenize(sentence)

print("BERT  tokens:", bert_tokens)
print("BERT  ids   :", bert_tokenizer.convert_tokens_to_ids(bert_tokens))
print("GPT-2 tokens:", gpt2_tokens)
print("GPT-2 ids   :", gpt2_tokenizer.convert_tokens_to_ids(gpt2_tokens))
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# BERT  tokens: ['transformers', 'is', 'amazing']
# BERT  ids   : [19081, 2003, 6429]
# GPT-2 tokens: ['Transform', 'ers', 'Ġis', 'Ġamazing']
# GPT-2 ids   : [41762, 364, 318, 4998]

# %% [markdown]
# ## Zero-Shot Classification

# %%
classifier = pipeline("zero-shot-classification")
classifier(
    "This tutorial is about transformer",
    candidate_labels=["education", "politics", "business"],
)
# Out:
# [transformers] No model was supplied, defaulted to facebook/bart-large-mnli and revision d7645e1.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/515 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# {'sequence': 'This is a course about the Transformers library',
#  'labels': ['education', 'business', 'politics'],
#  'scores': [0.8445985913276672, 0.11197450757026672, 0.04342687129974365]}

# %% [markdown]
# ## Text Generation (bonus / closer)

# %%
generator = pipeline("text-generation", model="distilgpt2")
generator(
    "In this tutorial, we will teach you how to",
    max_length=30,
    num_return_sequences=2,
)
# Out:
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# [transformers] Passing `generation_config` together with generation-related arguments=({'num_return_sequences', 'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer GPT2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# [{'generated_text': 'In this tutorial, we will teach you how to use a simple web app to view a list of items in the list.\n\n\n\nWhen you get to the list, you should see lists like:\nThe list of items in the list is only 2 items in the list. We will add a list of items in the list as well.\nThe list contains items in the list.\nThe list contains items in the list.\nThe list contains items in the list.\nThe list contains items in the list.\nThe list contains items in the list.\nThe list contains items in the list.\nThe list contains items in the list.\nThe list contains items in the list.\nThe list contains items in the list.\nThe list contains items in the list.\nThe list contains items in the list.\nThe list contains items in the list.\nThe list contains items in the list.\nThe list contains items in the list.\nThe list contains items in the list.\nThe list contains items in the list.\nThe list contains items in the list.\nThe list contains items in the list.\nThe list contains items in the list.\nThe list contains items in the list.\nThe list contains items in the list.\nThe list contains items in'},
#  {'generated_text': 'In this tutorial, we will teach you how to use the "Start Script" button to specify a script that will run the script, and then when it runs, it will run again.\n\n\n\nWe have created a script and a script that will run the script, and then when it runs, it will run again. Here is a basic script for the script.\nOnce the script finishes running, we will call it a script that will run the script.\nOnce the script finishes running, we will call it a script that will run the script.\nYou can see the script\'s main function.\nThe script will run the script in the same way it runs in the same way it runs in the same way it runs in the same way it runs in the same way it runs in the same way it runs in the same way it runs in the same way it runs in the same way it runs in the same way it runs in the same way it runs in the same way it runs in the same way it runs in the same way it runs in the same way it runs in the same way it runs in the same way it runs in the same way it runs in the same way it runs in the same way it runs in the same way it runs in the same way it runs in the same'}]

# %% [markdown]
# # Encoder only model

# %%
from sentence_transformers import SentenceTransformer, util

model = SentenceTransformer("all-MiniLM-L6-v2")

# Wrap your keywords in meaningful structural contexts
phrases = {
    "messi": "Lionel Messi is a famous professional football player.",
    "football": "Football is a popular team sport played with a ball.",
    "Hockey": "Hockey is a team sport played on ice with sticks."
}

vecs = {k: model.encode(v, convert_to_tensor=True) for k, v in phrases.items()}
print(vecs)
# Compute cosine similarities
sim_football = util.cos_sim(vecs["messi"], vecs["football"])
sim_hockey = util.cos_sim(vecs["messi"], vecs["Hockey"])

print(f"messi vs football: {sim_football.item():.4f}")  # Significantly higher
print(f"messi vs Hockey  : {sim_hockey.item():.4f}")    # Significantly lower
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# {'messi': tensor([ 2.8808e-02,  9.1313e-02, -9.2704e-03, -3.0736e-02, -1.2989e-02,
#          4.8520e-02,  1.0956e-01,  6.7468e-02,  8.6794e-02,  6.3186e-02,
#         -3.7817e-02, -1.0000e-01,  3.1298e-02,  6.8811e-02,  9.2344e-02,
#         -8.0722e-03, -3.4137e-02, -2.1183e-02, -1.0939e-02, -8.2535e-02,
#         -9.6923e-02, -2.4298e-02, -2.0813e-05, -2.8449e-02, -2.8397e-02,
#         -9.6658e-02,  1.9807e-02,  5.3404e-02, -7.6813e-02, -8.5007e-03,
#          4.5260e-03,  3.5077e-03, -9.1278e-03, -1.8916e-02, -2.5885e-02,
#          1.0028e-01,  2.9837e-02,  4.3545e-02,  9.7185e-02, -3.7708e-02,
#          1.4991e-02, -4.8934e-02, -1.6571e-02,  6.2958e-04,  8.6603e-02,
#         -4.0481e-02,  4.2689e-02, -5.2833e-03,  2.6276e-02,  1.6605e-02,
#         -5.6391e-02,  1.4129e-02,  3.7372e-02, -3.5324e-02,  9.1406e-02,
#         -1.4102e-03,  5.3837e-02,  1.5156e-02,  3.9655e-02,  4.0209e-02,
#         -3.0251e-02,  9.7914e-03,  6.0234e-03, -5.2741e-02, -1.5492e-02,
#         -2.1203e-02, -3.5408e-02, -3.5754e-03, -4.0644e-02,  5.3750e-02,
#          1.4895e-02, -1.3118e-02, -9.7003e-04,  6.8460e-02,  1.9235e-02,
#         -9.3519e-02, -2.2859e-02,  1.0513e-01,  7.4290e-02,  1.2255e-02,
#         -7.1913e-03, -1.0941e-01, -3.3575e-03, -5.8828e-02,  1.6253e-02,
#          5.2583e-02,  5.5641e-02, -2.2283e-02, -5.7194e-02,  8.5636e-02,
#          5.6363e-02, -5.5682e-02, -9.5266e-02, -1.0045e-01,  3.3353e-02,
#         -1.1983e-01,  2.5575e-02,  2.9031e-02, -3.3286e-02, -6.2016e-02,
#          2.9017e-02,  6.6617e-02, -2.9319e-02,  4.8217e-02,  1.5270e-02,
#          5.6582e-02, -1.0522e-02, -9.3723e-03, -2.1999e-03, -1.9877e-02,
#         -4.5858e-02, -7.8360e-02, -6.0287e-02, -6.8491e-02,  1.0390e-02,
#          9.3725e-03, -7.5233e-02,  1.0815e-01,  5.4975e-02,  5.8669e-02,
#         -7.9696e-04, -8.1027e-02, -1.6862e-02, -5.3038e-02, -1.5598e-02,
#          2.5803e-02,  1.1291e-02,  1.3280e-02,  3.3376e-02,  3.2408e-02,
#         -2.0901e-02, -2.6603e-02,  6.3301e-02,  3.0720e-02, -4.7635e-02,
#         -7.8588e-02, -5.8761e-02,  6.4022e-02, -9.3253e-02, -3.3285e-02,
#          4.8665e-02, -1.2430e-02, -6.0805e-02,  1.9349e-02,  1.6626e-03,
#          2.6829e-02,  1.7180e-02,  5.5366e-02, -1.9012e-02, -1.9890e-08,
#         -4.1906e-03,  1.2943e-01, -8.7405e-03, -1.1709e-02, -7.5482e-03,
#         -2.0588e-02, -2.5781e-02, -8.0987e-02, -1.4238e-02, -5.8917e-02,
#         -5.2580e-02, -6.9766e-03,  1.6938e-02, -1.1216e-02,  4.7565e-02,
#          1.8160e-02, -4.5743e-02,  1.8500e-02, -2.4030e-02, -2.3705e-02,
#         -2.2102e-02, -7.3377e-02, -3.3340e-02, -4.3748e-02, -7.3546e-02,
#         -4.1021e-02, -2.8446e-02,  4.2175e-02,  5.0117e-02, -4.2948e-03,
#         -2.4221e-02,  4.7224e-02,  5.6887e-02,  2.0346e-03,  7.5074e-02,
#         -1.9405e-02,  2.1480e-02, -7.2102e-02,  2.5149e-02,  8.4072e-03,
#         -8.1418e-02,  8.7119e-02, -2.9574e-03,  1.8320e-02, -5.8511e-02,
#          2.1773e-02, -3.4545e-02,  3.2714e-03, -5.7143e-02, -1.9445e-02,
#         -2.5350e-02,  4.6749e-02, -4.6384e-02,  1.5327e-02, -8.2638e-02,
#          9.1626e-02, -3.0300e-02,  2.5090e-03, -5.8255e-02,  1.6442e-02,
#         -5.7003e-02,  2.7546e-02,  8.1975e-02,  3.8905e-02])}
# messi vs football: 0.3847
# messi vs Hockey  : 0.1678

# %%
word1 = "king"
word2 = "man"
word3 = "queen"
word4 = "woman"

word5 = "football"

# king - man + woman = queen

embd1 = model.encode(word1)
embd2 = model.encode(word2)
embd3 = model.encode(word3)
embd4 = model.encode(word4)
embd5 = model.encode(word5)

# %%
result = embd1 - embd2 + embd4

# %%
sim1 = util.cos_sim(embd3, result)
sim2 = util.cos_sim(embd5, result)

print(sim1)
print(sim2)
# Out:
# tensor([[0.5795]])
# tensor([[0.1993]])
